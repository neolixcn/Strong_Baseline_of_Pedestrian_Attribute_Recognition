# %%
from pathlib import Path
from PIL import Image
import pdb
import json
import os
import cv2
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
gender = 0
shaonian=0
qingnian=0
zhongnian=0
laonian=0
maozi=0
yanjing=0
kouzhao=0
changxiu=0
duanxiu=0
changku=0
duanku=0
qunzi=0
qingdao=0
shangwuyuan=0
zhengxiang=0
chexiang=0
beixiang=0
lbBlack=0
lbGrey=0
lbBlue=0
lbGreen=0
lbWhite=0
lbBrown=0
lbPurple=0
lbRed=0
ubBlack=0
ubGrey=0
ubBlue=0
ubGreen=0
ubWhite=0
ubBrown=0
ubPurple=0
ubRed=0
ubPink=0
ubYellow=0
ubOrange=0
shang=['0809','0810',"0811","0812","0813",'0814','0815','0816','0817','0818','0819','0820','0821','0822','0823','0824','0825','0826','0729','0724','0722','0710']
n=0
yanse=['ub-Black', 'ub-Blue', 'ub-Brown', 'ub-Green', 'ub-Grey', 'ub-Orange', 'ub-Pink', 'ub-Purple', 'ub-Red', 'ub-White', 'ub-Yellow']
a=b=c=d=0
data = "/home/pantengteng/Programs/Strong_Baseline_of_Pedestrian_Attribute_Recognition/new_data.json"
reduced_data="/home/pantengteng/Programs/PROGRAMS_LANXIN"
image_name=os.listdir(reduced_data)
#print(image_name)
#pdb.set_trace()
with open(data, encoding="utf-8") as f:
    images = json.load(f)
    #pdb.set_trace()
for image in images:
    if image["img_name"] in image_name:
        image_name.remove(image["img_name"])
    n += 1
    if "Female" in image["attribute"]:
        gender += 1
    if "AgeLess16" in image["attribute"]:
        shaonian += 1
    if "Age17-45" in image["attribute"]:
        qingnian += 1
    if "Age46-60" in image["attribute"]:
        zhongnian += 1
    if "Ageover60" in image["attribute"]:
        laonian += 1
    if 'hs-Hat' in image["attribute"]:
        maozi += 1
    if 'hs-Glasses' in image["attribute"]:
        yanjing += 1
    if 'hs-mask' in image["attribute"]:
        kouzhao += 1   
    if 'ub-ShortSleeve' in image["attribute"]:
        changxiu += 1  
    if 'ub-LongSleeve' in image["attribute"]:
        duanxiu += 1  
    if 'lb-LongTrousers' in image["attribute"]:
        changku += 1  
    if 'lb-Shorts' in image["attribute"]:
        duanku += 1  
    if 'lb-Dress' in image["attribute"]:
        qunzi += 1  
    if 's-Leather' in image["attribute"]:
        a += 1  
    if 's-Sneaker' in image["attribute"]:
        b += 1  
    if 's-Boots' in image["attribute"]:
        c += 1  
    if 's-Sandals' in image["attribute"]:
        d += 1  
    if 'lb-Black' in image["attribute"]:
        lbBlack += 1  
    if 'lb-Grey' in image["attribute"]:
        lbGrey += 1
    if 'lb-Blue' in image["attribute"]:
        lbBlue += 1
    if 'lb-Green' in image["attribute"]:
        lbGreen += 1
    if 'lb-White' in image["attribute"]:
        lbWhite += 1
    if 'lb-Brown' in image["attribute"]:
        lbBrown += 1
    if 'lb-Purple' in image["attribute"]:
        lbPurple += 1
    if 'lb-Red' in image["attribute"]:
        lbRed += 1
    if 'ub-Black' in image["attribute"]:
        ubBlack += 1  
    if 'ub-Grey' in image["attribute"]:
        ubGrey += 1
    if 'ub-Blue' in image["attribute"]:
        ubBlue += 1
    if 'ub-Green' in image["attribute"]:
        ubGreen += 1
    if 'ub-White' in image["attribute"]:
        ubWhite += 1
    if 'ub-Brown' in image["attribute"]:
        ubBrown += 1
    if 'ub-Purple' in image["attribute"]:
        ubPurple += 1
    if 'ub-Red' in image["attribute"]:
        ubRed += 1
    if 'ub-Pink' in image["attribute"]:
        ubPink += 1
    if 'ub-Yellow' in image["attribute"]:
        ubYellow += 1
    if 'ub-Orange' in image["attribute"]:
        ubOrange += 1
        

    
    if 'Front' in image["attribute"]:
        zhengxiang += 1 
    if 'Side' in image["attribute"]:
        chexiang += 1 
    if 'Back' in image["attribute"]:
        beixiang += 1 
    if "0731" in image["img_name"]:
        qingdao += 1
    if "0801" in image["img_name"]:
        qingdao += 1
    if "0715" in image["img_name"]:
        qingdao += 1
    if "0716" in image["img_name"]:
        qingdao += 1
    for q in shang:
        if q in image["img_name"]:
            shangwuyuan += 1
    

#print(image_name)
print(n)
print(gender)
print("shaonian=",shaonian)
print("qingnian=",qingnian)
print("zhongnian=",zhongnian)
print("laonian=",laonian)
print("maozi=",maozi)
print("yanjing=",yanjing)
print("kouzhao=",kouzhao)
print("changxiu=",changxiu)
print("duanxiu=",duanxiu)
print(changku,duanku,qunzi,a,b,c,d)
print(qingdao,shangwuyuan)
print(zhengxiang,chexiang,beixiang,lbBlack,lbGrey,lbBlue,lbGreen,lbWhite,lbBrown,lbPurple,lbRed)
print(ubBlack, ubBlue, ubBrown, ubGreen, ubGrey, ubOrange, ubPink, ubPurple, ubRed, ubWhite,ubYellow)
# Out:
# 140
# 53
# shaonian= 12
# qingnian= 99
# zhongnian= 27
# laonian= 1
# maozi= 33
# yanjing= 44
# kouzhao= 49
# changxiu= 107
# duanxiu= 32
# 102 24 9 14 84 2 7
# 19 108
# 92 37 11 63 15 30 5 10 9 1 2
# 27 30 4 10 13 0 9 2 9 50 2
